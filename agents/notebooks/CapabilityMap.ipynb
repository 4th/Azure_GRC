# %% [markdown]
# 🧠 Install Semantic Kernel
#
# To use Microsoft’s Semantic Kernel for orchestrating AI agents, planners, and connectors, install the latest version from PyPI using pip.
# Run the following command in a code cell below:

# %%
pip install -U semantic-kernel
# Out:
# Collecting semantic-kernel
#   Downloading semantic_kernel-1.37.1-py3-none-any.whl.metadata (13 kB)
# Collecting azure-ai-projects>=1.0.0b12 (from semantic-kernel)
#   Downloading azure_ai_projects-1.1.0b4-py3-none-any.whl.metadata (24 kB)
# Collecting azure-ai-agents>=1.2.0b3 (from semantic-kernel)
#   Downloading azure_ai_agents-1.2.0b6-py3-none-any.whl.metadata (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp~=3.8 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (3.13.2)
# Collecting cloudevents~=1.0 (from semantic-kernel)
#   Downloading cloudevents-1.12.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (2.11.10)
# Requirement already satisfied: pydantic-settings~=2.0 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (2.11.0)
# Requirement already satisfied: defusedxml~=0.7 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (0.7.1)
# Collecting azure-identity>=1.13 (from semantic-kernel)
#   Downloading azure_identity-1.25.1-py3-none-any.whl.metadata (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (2.0.2)
# Requirement already satisfied: openai<2.0.0,>=1.98.0 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (1.109.1)
# Collecting openapi_core<0.20,>=0.18 (from semantic-kernel)
#   Downloading openapi_core-0.19.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: websockets<16,>=13 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (15.0.1)
# Collecting aiortc>=1.9.0 (from semantic-kernel)
#   Downloading aiortc-1.14.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: opentelemetry-api~=1.24 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (1.37.0)
# Collecting prance<25.4.9,>=23.6.21 (from semantic-kernel)
#   Downloading prance-25.4.8.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybars4~=0.9 (from semantic-kernel)
#   Downloading pybars4-0.9.13.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jinja2~=3.1 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (3.1.6)
# Requirement already satisfied: nest-asyncio~=1.6 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (1.16.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (5.29.5)
# Requirement already satisfied: typing-extensions>=4.13 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (1.22.0)
# Collecting aioice<1.0.0,>=0.10.1 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading aioice-0.10.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting av<17.0.0,>=14.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading av-16.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting cryptography>=44.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading cryptography-46.0.3-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: google-crc32c>=1.1 in /usr/local/lib/python3.12/dist-packages (from aiortc>=1.9.0->semantic-kernel) (1.7.1)
# Collecting pyee>=13.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading pylibsrtp-1.0.0-cp310-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Collecting pyopenssl>=25.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading pyopenssl-25.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting isodate>=0.6.1 (from azure-ai-agents>=1.2.0b3->semantic-kernel)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-core>=1.30.0 (from azure-ai-agents>=1.2.0b3->semantic-kernel)
#   Downloading azure_core-1.36.0-py3-none-any.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 2.6 MB/s eta 0:00:00
# Collecting azure-storage-blob>=12.15.0 (from azure-ai-projects>=1.0.0b12->semantic-kernel)
#   Downloading azure_storage_blob-12.27.1-py3-none-any.whl.metadata (26 kB)
# Collecting msal>=1.30.0 (from azure-identity>=1.13->semantic-kernel)
#   Downloading msal-1.34.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity>=1.13->semantic-kernel)
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting deprecation<3.0,>=2.0 (from cloudevents~=1.0->semantic-kernel)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2~=3.1->semantic-kernel) (3.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.98.0->semantic-kernel) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.98.0->semantic-kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.98.0->semantic-kernel) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.98.0->semantic-kernel) (0.11.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.98.0->semantic-kernel) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.98.0->semantic-kernel) (4.67.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (4.25.1)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading jsonschema_path-0.3.4-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (10.8.0)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading openapi_schema_validator-0.6.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading openapi_spec_validator-0.7.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug<3.1.2 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading werkzeug-3.1.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api~=1.24->semantic-kernel) (8.7.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk~=1.24->semantic-kernel) (0.58b0)
# Requirement already satisfied: chardet>=5.2 in /usr/local/lib/python3.12/dist-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (5.2.0)
# Collecting ruamel.yaml>=0.18.10 (from prance<25.4.9,>=23.6.21->semantic-kernel)
#   Downloading ruamel.yaml-0.18.16-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (2.32.4)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (25.0)
# Collecting PyMeta3>=0.5.1 (from pybars4~=0.9->semantic-kernel)
#   Downloading PyMeta3-0.5.1.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings~=2.0->semantic-kernel) (1.2.1)
# Collecting dnspython>=2.0.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel)
#   Downloading ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.98.0->semantic-kernel) (3.11)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=44.0.0->aiortc>=1.9.0->semantic-kernel) (2.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.98.0->semantic-kernel) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.98.0->semantic-kernel) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.98.0->semantic-kernel) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.28.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (6.0.3)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading pathable-0.4.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity>=1.13->semantic-kernel) (2.10.1)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.1.4)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading lazy_object_proxy-1.12.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->prance<25.4.9,>=23.6.21->semantic-kernel) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->prance<25.4.9,>=23.6.21->semantic-kernel) (2.5.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.18.10->prance<25.4.9,>=23.6.21->semantic-kernel)
#   Downloading ruamel.yaml.clib-0.2.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=44.0.0->aiortc>=1.9.0->semantic-kernel) (2.23)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from rfc3339-validator->openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (1.17.0)
# Downloading semantic_kernel-1.37.1-py3-none-any.whl (893 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 893.8/893.8 kB 31.1 MB/s eta 0:00:00
# Downloading aiortc-1.14.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.0 MB/s eta 0:00:00
# Downloading azure_ai_agents-1.2.0b6-py3-none-any.whl (217 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.9/217.9 kB 12.9 MB/s eta 0:00:00
# Downloading azure_ai_projects-1.1.0b4-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 8.0 MB/s eta 0:00:00
# Downloading azure_identity-1.25.1-py3-none-any.whl (191 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.3/191.3 kB 12.1 MB/s eta 0:00:00
# Downloading cloudevents-1.12.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 3.7 MB/s eta 0:00:00
# Downloading openapi_core-0.19.5-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 7.1 MB/s eta 0:00:00
# Downloading prance-25.4.8.0-py3-none-any.whl (36 kB)
# Downloading aioice-0.10.1-py3-none-any.whl (24 kB)
# Downloading av-16.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (40.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 25.2 MB/s eta 0:00:00
# Downloading azure_core-1.36.0-py3-none-any.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.3/213.3 kB 13.5 MB/s eta 0:00:00
# Downloading azure_storage_blob-12.27.1-py3-none-any.whl (428 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 429.0/429.0 kB 26.7 MB/s eta 0:00:00
# Downloading cryptography-46.0.3-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 111.3 MB/s eta 0:00:00
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading jsonschema_path-0.3.4-py3-none-any.whl (14 kB)
# Downloading msal-1.34.0-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.5 MB/s eta 0:00:00
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Downloading openapi_schema_validator-0.6.3-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.2-py3-none-any.whl (39 kB)
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Downloading pylibsrtp-1.0.0-cp310-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 64.9 MB/s eta 0:00:00
# Downloading pyopenssl-25.3.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.4 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.16-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 7.6 MB/s eta 0:00:00
# Downloading werkzeug-3.1.1-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.4/224.4 kB 13.1 MB/s eta 0:00:00
# Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 19.0 MB/s eta 0:00:00
# Downloading ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Downloading lazy_object_proxy-1.12.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.0 MB/s eta 0:00:00
# Downloading pathable-0.4.4-py3-none-any.whl (9.6 kB)
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading ruamel.yaml.clib-0.2.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (753 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.1/753.1 kB 39.8 MB/s eta 0:00:00
# Building wheels for collected packages: pybars4, PyMeta3
#   Building wheel for pybars4 (setup.py) ... done
#   Created wheel for pybars4: filename=pybars4-0.9.13-py3-none-any.whl size=14340 sha256=7955de25f1dd1e61d0c2ccf38653429002e289cd666fc69102d706fbb9374ae1
#   Stored in directory: /root/.cache/pip/wheels/75/2d/da/c75b2fc7b00dc9c154dff65f689a318e7d24b44c612c2b21f1
#   Building wheel for PyMeta3 (setup.py) ... done
#   Created wheel for PyMeta3: filename=PyMeta3-0.5.1-py3-none-any.whl size=16449 sha256=4e4dd577769ca0588a9e57d6ce05433ba5b93369dae6506fa7cbf02c5aad54ef
#   Stored in directory: /root/.cache/pip/wheels/5a/9b/2c/81b7551d2c05a482817e6c3b3d2f8ad2a0229db874c4bc6346
# Successfully built pybars4 PyMeta3
# Installing collected packages: PyMeta3, parse, ifaddr, werkzeug, ruamel.yaml.clib, referencing, pyee, pybars4, pathable, lazy-object-proxy, isodate, dnspython, deprecation, av, ruamel.yaml, pylibsrtp, jsonschema-path, cryptography, cloudevents, azure-core, aioice, pyopenssl, prance, azure-storage-blob, azure-ai-agents, openapi-schema-validator, msal, azure-ai-projects, aiortc, openapi-spec-validator, msal-extensions, openapi_core, azure-identity, semantic-kernel
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: referencing
#     Found existing installation: referencing 0.37.0
#     Uninstalling referencing-0.37.0:
#       Successfully uninstalled referencing-0.37.0
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: pyopenssl
#     Found existing installation: pyOpenSSL 24.2.1
#     Uninstalling pyOpenSSL-24.2.1:
#       Successfully uninstalled pyOpenSSL-24.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# Successfully installed PyMeta3-0.5.1 aioice-0.10.1 aiortc-1.14.0 av-16.0.1 azure-ai-agents-1.2.0b6 azure-ai-projects-1.1.0b4 azure-core-1.36.0 azure-identity-1.25.1 azure-storage-blob-12.27.1 cloudevents-1.12.0 cryptography-46.0.3 deprecation-2.1.0 dnspython-2.8.0 ifaddr-0.2.0 isodate-0.7.2 jsonschema-path-0.3.4 lazy-object-proxy-1.12.0 msal-1.34.0 msal-extensions-1.3.1 openapi-schema-validator-0.6.3 openapi-spec-validator-0.7.2 openapi_core-0.19.5 parse-1.20.2 pathable-0.4.4 prance-25.4.8.0 pybars4-0.9.13 pyee-13.0.0 pylibsrtp-1.0.0 pyopenssl-25.3.0 referencing-0.36.2 ruamel.yaml-0.18.16 ruamel.yaml.clib-0.2.14 semantic-kernel-1.37.1 werkzeug-3.1.1

# %% [markdown]
# 💡 Note: Removing pydrive2
#
# If you see dependency warnings about cryptography or pyOpenSSL when installing Azure packages, they usually come from pydrive2, which Colab preinstalls for legacy Google Drive APIs.
# You don’t actually need pydrive2 for Drive access anymore — Colab’s built-in drive.mount() handles everything.
#
# To remove it safely and avoid version conflicts, run:

# %%
# !pip -q uninstall -y pydrive2

# %% [markdown]
# 🤖 Connect to Azure OpenAI in Colab
#
# The following code shows how to connect Google Colab to your Azure OpenAI resource using the official openai Python package.
#
# Import the AzureOpenAI client class.
#
# Initialize it with your Azure OpenAI endpoint, API key, and API version.
#
# Use your deployment name (for example, gpt-35-turbo) as the model parameter when sending chat requests.
#
# Print the assistant’s response.
#
# ⚠️ Security Note: Never share your real API key in public notebooks or commits.
# Instead, store it in an environment variable (for example,
# os.environ["AZURE_OPENAI_API_KEY"]) and reference it securely in your code.
#
# Run the next code cell to send a test message to your Azure OpenAI deployment and confirm the connection from Colab.

# %%
from openai import AzureOpenAI

# Initialize client
client = AzureOpenAI(
    api_key="INSERT_KEY",
    azure_endpoint="INSERT_ENDPOINT}",
    api_version="2024-10-21"
)

# Correct model name = deployment name (not 'gpt-4' etc.)
response = client.chat.completions.create(
    model="gpt-35-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful AI assistant."},
        {"role": "user", "content": "Hello from Colab and Azure OpenAI!"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Hello! How can I assist you today?

# %% [markdown]
# 🧠 Installing Microsoft Agentic Framework Dependencies
#
# Before running Azure OpenAI or the Microsoft Agent Framework in Colab, you’ll need to install the latest compatible SDKs and libraries.
# This command ensures that Semantic Kernel, Azure AI Agents, and OpenAI are all properly aligned to avoid version conflicts.
#
# This installs:
#
# 🧩 semantic-kernel – orchestrates AI workflows and prompt pipelines
#
# 🔐 azure-identity – handles secure authentication with Azure services
#
# ☁️ azure-ai-projects – project management and AI service integration
#
# 🤖 azure-ai-agents – enables creation of tool-using and multi-agent systems
#
# 💬 openai – communicates with Azure OpenAI endpoints for completions and chat
#
# ✅ Tip: Run this cell once per Colab session before importing any Azure or Semantic Kernel packages.

# %%
# !pip -q install -U "semantic-kernel==1.37.1" "azure-identity>=1.25.1" "azure-ai-projects==1.1.0b4" "azure-ai-agents==1.2.0b5" "openai>=1.98"

# %% [markdown]
# 📂 Work with Google Drive in Colab
#
# Use this cell to mount your Google Drive, inspect files, create a project folder, and read/write a CSV. It avoids pydrive2 by using Colab’s native mount.

# %%
# 1) Mount Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)   # follow the auth link

# 2) Your files live under /content/drive/MyDrive
import os, pathlib, pandas as pd

base = pathlib.Path("/content/drive/MyDrive")
print("Root exists?", base.exists())
print("Sample listing:", os.listdir(base)[:10])

# 3) Create a folder and write a file
proj = base / "azure_agentic_demo"
proj.mkdir(exist_ok=True)
(proj / "hello.txt").write_text("Hello from Colab!")

# 4) Save & read a CSV
df = pd.DataFrame({"a":[1,2,3], "b":["x","y","z"]})
csv_path = proj / "sample.csv"
df.to_csv(csv_path, index=False)
print("Saved:", csv_path)

pd.read_csv(csv_path).head()
# Out:
# Mounted at /content/drive
# Root exists? True
# Sample listing: ['pdfcoffee.com_ncees-fe-electrical-practice-exam1pdf-pdf-free.pdf', 'pdfcoffee.com_noson-s-yanofsky-mirco-a-mannucci-quantum-computing-for-computer-scientists-cambridge-university-press-2008-pdf-free.pdf', 'pdfcoffee.com_the-impact-of-artificial-intelligence-on-communication-pdf-free.pdf', 'vdoc.pub_programming-quantum-computers-essential-algorithms-and-code-samples.pdf', 'vdoc.pub_fe-electrical-and-computer-practice-problems.pdf', 'quantum_fractals (1).docx', 'quantum_fractals.docx', 'dokumen.pub_david-bohm-a-life-dedicated-to-understanding-the-quantum-world-3030227146.pdf', 'vdoc.pub_techniques-and-applications-of-path-integration.pdf', 'dokumen.pub_julian-schwinger-the-physicist-the-teacher-and-the-man-9810225318-9810225326.pdf']
# Saved: /content/drive/MyDrive/azure_agentic_demo/sample.csv
#    a  b
# 0  1  x
# 1  2  y
# 2  3  z

# %% [markdown]
# 🔑 Configure Azure OpenAI Environment Variables
#
# Set up your Azure credentials so Colab can authenticate directly with your Azure OpenAI resource.
# Replace the sample API key and endpoint below with your own values from the Azure Portal (Keys and Endpoint section).

# %%
import os
os.environ["AZURE_OPENAI_ENDPOINT"]   = "https://4th-openai-resource.openai.azure.com"
os.environ["AZURE_OPENAI_API_KEY"]    = "XXXX"   # from Keys & Endpoints
os.environ["AZURE_OPENAI_API_VERSION"]= "2024-10-21"
os.environ["AZURE_OPENAI_DEPLOYMENT"] = "gpt-35-turbo"    # your deployment name

# %% [markdown]
# ✅ Quick sanity check: call your Azure OpenAI deployment
#
# Run this cell to verify your environment variables and deployment are working. It should print a short greeting; if anything’s misconfigured, you’ll see a clear error.

# %%
from openai import AzureOpenAI, OpenAIError
client = AzureOpenAI(
    api_key=os.environ["AZURE_OPENAI_API_KEY"],
    api_version=os.environ["AZURE_OPENAI_API_VERSION"],
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
)

try:
    r = client.chat.completions.create(
        model=os.environ["AZURE_OPENAI_DEPLOYMENT"],
        messages=[{"role":"user","content":"Say hi in one short line."}]
    )
    print(r.choices[0].message.content)
except OpenAIError as e:
    print("ERROR:", e)
# Out:
# Hello!

# %% [markdown]
# 🧪 Tool-calling demo: simple agent with a timezone tool
#
# This cell shows a minimal agent loop using Azure OpenAI tool-calling. The model decides when to call the get_timezone tool, you run the tool in Python, then feed the result back for a final answer.

# %%
import json, datetime as dt

def get_timezone(city:str)->str:
    # stub tool; replace with real logic as needed
    return f"Timezone for {city}: US/Eastern (stub) @ {dt.datetime.now().isoformat(timespec='seconds')}"

tools = [{
    "type":"function",
    "function":{
        "name":"get_timezone",
        "description":"Return a timezone for a US city",
        "parameters":{"type":"object",
                      "properties":{"city":{"type":"string"}},
                      "required":["city"]},
    },
}]

messages=[{"role":"system","content":"You are concise and call tools when helpful."},
          {"role":"user","content":"What timezone is Tallahassee in?"}]

resp = client.chat.completions.create(
    model=os.environ["AZURE_OPENAI_DEPLOYMENT"],
    messages=messages,
    tools=tools,
    tool_choice="auto",
)
msg = resp.choices[0].message
messages.append(msg)

if msg.tool_calls:
    for call in msg.tool_calls:
        args = json.loads(call.function.arguments or "{}")
        result = get_timezone(**args)
        messages.append({
            "role":"tool",
            "tool_call_id":call.id,
            "name":call.function.name,
            "content": result
        })
    final = client.chat.completions.create(
        model=os.environ["AZURE_OPENAI_DEPLOYMENT"],
        messages=messages
    )
    print(final.choices[0].message.content)
else:
    print(msg.content)
# Out:
# Tallahassee is in the US Eastern timezone.

# %% [markdown]
# 💾 Save conversation to Google Drive (normalize SDK objects → JSON)
#
# This cell converts any SDK message objects (like ChatCompletionMessage) into plain dicts so they’re JSON-serializable, then writes the transcript to Drive.

# %%
# Normalize OpenAI message objects -> plain dicts, then save to Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import pathlib, json

def normalize_messages(msgs):
    out = []
    for m in msgs:
        if isinstance(m, dict):
            out.append(m)
            continue
        item = {"role": getattr(m, "role", None), "content": getattr(m, "content", None)}
        # include tool calls if present
        tcs = getattr(m, "tool_calls", None)
        if tcs:
            item["tool_calls"] = [
                {
                    "id": tc.id,
                    "type": "function",
                    "function": {
                        "name": getattr(tc.function, "name", None),
                        "arguments": getattr(tc.function, "arguments", None),
                    },
                }
                for tc in tcs
            ]
        # include name if present (e.g., tool messages)
        name = getattr(m, "name", None)
        if name: item["name"] = name
        out.append(item)
    return out

log_dir = pathlib.Path("/content/drive/MyDrive/azure_agentic_demo")
log_dir.mkdir(exist_ok=True)
normalized = normalize_messages(messages)
path = log_dir / "conversation.json"
path.write_text(json.dumps(normalized, indent=2))
print(f"Saved {path}")
# Out:
# Mounted at /content/drive
# Saved /content/drive/MyDrive/azure_agentic_demo/conversation.json

# %% [markdown]
# ⚙️ Install Microsoft Agent Framework (Preview)
#
# Run this cell to install the Microsoft Agent Framework (pre-release version) into your Colab environment:

# %%
pip install agent-framework --pre
# Out:
# Requirement already satisfied: agent-framework in /usr/local/lib/python3.12/dist-packages (1.0.0b251105)
# Requirement already satisfied: agent-framework-core in /usr/local/lib/python3.12/dist-packages (from agent-framework) (1.0.0b251105)
# Requirement already satisfied: agent-framework-a2a in /usr/local/lib/python3.12/dist-packages (from agent-framework) (1.0.0b251105)
# Requirement already satisfied: agent-framework-ag-ui in /usr/local/lib/python3.12/dist-packages (from agent-framework) (1.0.0b251106.post1)
# Requirement already satisfied: agent-framework-anthropic in /usr/local/lib/python3.12/dist-packages (from agent-framework) (1.0.0b251105)
# Requirement already satisfied: agent-framework-azure-ai in /usr/local/lib/python3.12/dist-packages (from agent-framework) (1.0.0b251105)
# Requirement already satisfied: agent-framework-chatkit in /usr/local/lib/python3.12/dist-packages (from agent-framework) (1.0.0b251105)
# Requirement already satisfied: agent-framework-copilotstudio in /usr/local/lib/python3.12/dist-packages (from agent-framework) (1.0.0b251105)
# Requirement already satisfied: agent-framework-devui in /usr/local/lib/python3.12/dist-packages (from agent-framework) (1.0.0b251105)
# Requirement already satisfied: agent-framework-lab in /usr/local/lib/python3.12/dist-packages (from agent-framework) (1.0.0b251024)
# Requirement already satisfied: agent-framework-mem0 in /usr/local/lib/python3.12/dist-packages (from agent-framework) (1.0.0b251105)
# Requirement already satisfied: agent-framework-purview in /usr/local/lib/python3.12/dist-packages (from agent-framework) (1.0.0b251105)
# Requirement already satisfied: agent-framework-redis in /usr/local/lib/python3.12/dist-packages (from agent-framework) (1.0.0b251105)
# Requirement already satisfied: a2a-sdk>=0.3.5 in /usr/local/lib/python3.12/dist-packages (from agent-framework-a2a->agent-framework) (0.3.10)
# Requirement already satisfied: ag-ui-protocol>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from agent-framework-ag-ui->agent-framework) (0.2.0a0)
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from agent-framework-ag-ui->agent-framework) (0.121.0)
# Requirement already satisfied: uvicorn>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from agent-framework-ag-ui->agent-framework) (0.38.0)
# Requirement already satisfied: anthropic<1,>=0.70.0 in /usr/local/lib/python3.12/dist-packages (from agent-framework-anthropic->agent-framework) (0.72.0)
# Requirement already satisfied: azure-ai-projects>=1.0.0b11 in /usr/local/lib/python3.12/dist-packages (from agent-framework-azure-ai->agent-framework) (1.1.0b4)
# Requirement already satisfied: azure-ai-agents==1.2.0b5 in /usr/local/lib/python3.12/dist-packages (from agent-framework-azure-ai->agent-framework) (1.2.0b5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from agent-framework-azure-ai->agent-framework) (3.13.2)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /usr/local/lib/python3.12/dist-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework) (4.15.0)
# Requirement already satisfied: openai-chatkit<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from agent-framework-chatkit->agent-framework) (1.1.1)
# Requirement already satisfied: microsoft-agents-copilotstudio-client>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from agent-framework-copilotstudio->agent-framework) (0.6.0.dev10)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.12/dist-packages (from agent-framework-core->agent-framework) (2.12.4)
# Requirement already satisfied: pydantic-settings<3,>=2 in /usr/local/lib/python3.12/dist-packages (from agent-framework-core->agent-framework) (2.11.0)
# Requirement already satisfied: opentelemetry-api>=1.24 in /usr/local/lib/python3.12/dist-packages (from agent-framework-core->agent-framework) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.24 in /usr/local/lib/python3.12/dist-packages (from agent-framework-core->agent-framework) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.36.0 in /usr/local/lib/python3.12/dist-packages (from agent-framework-core->agent-framework) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /usr/local/lib/python3.12/dist-packages (from agent-framework-core->agent-framework) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in /usr/local/lib/python3.12/dist-packages (from agent-framework-core->agent-framework) (2.7.1)
# Requirement already satisfied: azure-identity<2,>=1 in /usr/local/lib/python3.12/dist-packages (from agent-framework-core->agent-framework) (1.25.1)
# Requirement already satisfied: mcp>=1.13 in /usr/local/lib/python3.12/dist-packages (from mcp[ws]>=1.13->agent-framework-core->agent-framework) (1.20.0)
# Requirement already satisfied: packaging>=24.1 in /usr/local/lib/python3.12/dist-packages (from agent-framework-core->agent-framework) (25.0)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from agent-framework-devui->agent-framework) (1.2.1)
# Requirement already satisfied: mem0ai>=0.1.117 in /usr/local/lib/python3.12/dist-packages (from agent-framework-mem0->agent-framework) (1.0.0)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from agent-framework-purview->agent-framework) (0.28.1)
# Requirement already satisfied: redis>=6.4.0 in /usr/local/lib/python3.12/dist-packages (from agent-framework-redis->agent-framework) (6.4.0)
# Requirement already satisfied: redisvl>=0.8.2 in /usr/local/lib/python3.12/dist-packages (from agent-framework-redis->agent-framework) (0.10.0)
# Requirement already satisfied: numpy>=2.2.6 in /usr/local/lib/python3.12/dist-packages (from agent-framework-redis->agent-framework) (2.3.4)
# Requirement already satisfied: google-api-core>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (2.28.1)
# Requirement already satisfied: httpx-sse>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (0.4.3)
# Requirement already satisfied: protobuf>=5.29.5 in /usr/local/lib/python3.12/dist-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (5.29.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic->agent-framework) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic->agent-framework) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic->agent-framework) (0.17.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic->agent-framework) (0.11.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic->agent-framework) (1.3.1)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /usr/local/lib/python3.12/dist-packages (from azure-ai-projects>=1.0.0b11->agent-framework-azure-ai->agent-framework) (12.27.1)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework) (2.32.4)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.12/dist-packages (from azure-identity<2,>=1->agent-framework-core->agent-framework) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in /usr/local/lib/python3.12/dist-packages (from azure-identity<2,>=1->agent-framework-core->agent-framework) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from azure-identity<2,>=1->agent-framework-core->agent-framework) (1.3.1)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->agent-framework-ag-ui->agent-framework) (0.49.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->agent-framework-ag-ui->agent-framework) (0.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->agent-framework-purview->agent-framework) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->agent-framework-purview->agent-framework) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->agent-framework-purview->agent-framework) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->agent-framework-purview->agent-framework) (0.16.0)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (4.25.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (3.0.3)
# Requirement already satisfied: websockets>=15.0.1 in /usr/local/lib/python3.12/dist-packages (from mcp[ws]>=1.13->agent-framework-core->agent-framework) (15.0.1)
# Requirement already satisfied: posthog>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (6.9.0)
# Requirement already satisfied: pytz>=2024.1 in /usr/local/lib/python3.12/dist-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (1.15.1)
# Requirement already satisfied: sqlalchemy>=2.0.31 in /usr/local/lib/python3.12/dist-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (2.0.44)
# Requirement already satisfied: microsoft-agents-hosting-core==0.6.0.dev10 in /usr/local/lib/python3.12/dist-packages (from microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework) (0.6.0.dev10)
# Requirement already satisfied: microsoft-agents-activity==0.6.0.dev10 in /usr/local/lib/python3.12/dist-packages (from microsoft-agents-hosting-core==0.6.0.dev10->microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework) (0.6.0.dev10)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.0->agent-framework-core->agent-framework) (4.67.1)
# Requirement already satisfied: openai-agents>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from openai-chatkit<2.0.0,>=1.1.0->agent-framework-chatkit->agent-framework) (0.5.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.24->agent-framework-core->agent-framework) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework) (1.71.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework) (1.76.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.24->agent-framework-core->agent-framework) (0.59b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->agent-framework-core->agent-framework) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->agent-framework-core->agent-framework) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->agent-framework-core->agent-framework) (0.4.2)
# Requirement already satisfied: jsonpath-ng>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework) (1.7.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework) (0.5.3)
# Requirement already satisfied: python-ulid>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework) (3.1.0)
# Requirement already satisfied: pyyaml<7.0,>=5.4 in /usr/local/lib/python3.12/dist-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework) (6.0.3)
# Requirement already satisfied: tenacity>=8.2.2 in /usr/local/lib/python3.12/dist-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework) (8.5.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.30.0->agent-framework-ag-ui->agent-framework) (8.3.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework) (1.1.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->agent-framework-azure-ai->agent-framework) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->agent-framework-azure-ai->agent-framework) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->agent-framework-azure-ai->agent-framework) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->agent-framework-azure-ai->agent-framework) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->agent-framework-azure-ai->agent-framework) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->agent-framework-azure-ai->agent-framework) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->agent-framework-azure-ai->agent-framework) (1.22.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core->agent-framework) (2.0.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (2.38.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.24->agent-framework-core->agent-framework) (3.23.0)
# Requirement already satisfied: ply in /usr/local/lib/python3.12/dist-packages (from jsonpath-ng>=1.5.0->redisvl>=0.8.2->agent-framework-redis->agent-framework) (3.11)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (0.28.0)
# Requirement already satisfied: griffe<2,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.1.0->agent-framework-chatkit->agent-framework) (1.14.0)
# Requirement already satisfied: types-requests<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.1.0->agent-framework-chatkit->agent-framework) (2.32.4.20250913)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (2.2.1)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /usr/local/lib/python3.12/dist-packages (from qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework) (3.4.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=2.0.31->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (3.2.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core->agent-framework) (2.23)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (4.9.1)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.12/dist-packages (from griffe<2,>=1.5.6->openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.1.0->agent-framework-chatkit->agent-framework) (0.4.6)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (4.1.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (0.6.1)

# %%
# === RAG over Drive files (PDF/DOCX/TXT/MD) => embed (local) => retrieve => answer with Azure OpenAI ===
# Turnkey single cell for Google Colab

# --- Install deps (idempotent) ---
import sys, subprocess, importlib
def pip_install(pkgs):
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-U", *pkgs], check=True)

for mod, pkgs in {
    "faiss": ["faiss-cpu"],
    "sentence_transformers": ["sentence-transformers"],
    "pypdf": ["pypdf"],
    "docx2txt": ["docx2txt"],
}.items():
    try:
        importlib.import_module(mod)
    except Exception:
        pip_install(pkgs)

# --- Imports ---
from google.colab import drive
from pypdf import PdfReader
import docx2txt
import os, pathlib, re, json, hashlib, pickle
import numpy as np, faiss
from sentence_transformers import SentenceTransformer
from openai import AzureOpenAI

# --- Mount Drive ---
drive.mount("/content/drive", force_remount=True)

# ========================= CONFIG =========================
# Put your docs into this folder in Drive:
DATA_DIR = pathlib.Path("/content/drive/MyDrive")
DATA_DIR.mkdir(exist_ok=True)

# Where to save FAISS and metadata:
INDEX_DIR = pathlib.Path("/content/drive/MyDrive/RAG_index")
INDEX_DIR.mkdir(exist_ok=True)

# Ask your question here:
QUESTION = "Summarize the key policies and dates from the syllabus."
TOP_K = 5
# =========================================================

print("Place files in:", DATA_DIR)
print("Found files:", [p.name for p in DATA_DIR.iterdir() if p.suffix.lower() in [".pdf",".docx",".txt",".md"]])

# --- Utilities: load & chunk ---
def read_file(path: pathlib.Path) -> str:
    suf = path.suffix.lower()
    if suf == ".pdf":
        text = []
        with open(path, "rb") as f:
            reader = PdfReader(f)
            for pg in reader.pages:
                text.append(pg.extract_text() or "")
        return "\n".join(text)
    if suf == ".docx":
        return docx2txt.process(str(path)) or ""
    if suf in [".txt", ".md"]:
        return path.read_text(errors="ignore")
    return ""

def clean_text(s: str) -> str:
    s = s.replace("\x00", " ")
    s = re.sub(r"\s+\n", "\n", s)
    s = re.sub(r"\n{3,}", "\n\n", s)
    return s.strip()

def chunk_text(text: str, max_words=300, overlap=60):
    words = text.split()
    chunks = []
    i = 0
    while i < len(words):
        chunk = words[i:i+max_words]
        if not chunk: break
        chunks.append(" ".join(chunk))
        i += max_words - overlap
    return chunks

def file_digest(path: pathlib.Path):
    h = hashlib.sha256()
    with open(path, "rb") as f:
        for b in iter(lambda: f.read(1 << 20), b""):
            h.update(b)
    return h.hexdigest()

# --- Gather docs -> chunks + metadata ---
docs = []
file_hashes = {}
for p in sorted(DATA_DIR.iterdir()):
    if p.suffix.lower() not in [".pdf", ".docx", ".txt", ".md"]:
        continue
    raw = read_file(p)
    txt = clean_text(raw)
    if not txt.strip():
        continue
    fh = file_digest(p)
    file_hashes[p.name] = fh
    for j, ch in enumerate(chunk_text(txt, max_words=300, overlap=60)):
        docs.append({"doc": p.name, "digest": fh, "chunk_id": j, "text": ch})

if not docs:
    raise SystemExit("No supported documents found. Add PDF/DOCX/TXT/MD files to /MyDrive/RAG_docs and rerun.")

print(f"Prepared {len(docs)} chunks from {len(file_hashes)} files.")

# --- Build or load embeddings + FAISS ---
embed_model_name = "sentence-transformers/all-MiniLM-L6-v2"
embed_model = SentenceTransformer(embed_model_name)

index_path = INDEX_DIR / "index.faiss"
meta_path  = INDEX_DIR / "meta.pkl"
hash_path  = INDEX_DIR / "file_hashes.json"

rebuild = True
if index_path.exists() and meta_path.exists() and hash_path.exists():
    try:
        old_hashes = json.loads(hash_path.read_text())
        if old_hashes == file_hashes:
            # Load existing index/meta
            index = faiss.read_index(str(index_path))
            with open(meta_path, "rb") as f:
                meta_docs = pickle.load(f)
            # Sanity: meta_docs should match docs length; if not, rebuild
            if len(meta_docs) == len(docs):
                docs = meta_docs
                rebuild = False
    except Exception:
        pass

if rebuild:
    print("Embedding and indexing…")
    embs = embed_model.encode(
        [d["text"] for d in docs],
        batch_size=64,
        show_progress_bar=True,
        normalize_embeddings=True
    )
    embs = np.asarray(embs, dtype="float32")
    index = faiss.IndexFlatIP(embs.shape[1])  # cosine (with normalized vectors)
    index.add(embs)
    faiss.write_index(index, str(index_path))
    with open(meta_path, "wb") as f:
        pickle.dump(docs, f)
    hash_path.write_text(json.dumps(file_hashes, indent=2))
    print(f"Indexed {len(docs)} chunks.")
else:
    print("Loaded existing index.")

# --- Retriever ---
def retrieve(query: str, k=TOP_K):
    qvec = embed_model.encode([query], normalize_embeddings=True)
    D, I = index.search(np.asarray(qvec, dtype="float32"), k)
    results = []
    for rank, i in enumerate(I[0]):
        if i == -1: continue
        m = docs[i]
        results.append({
            "rank": rank + 1,
            "score": float(D[0][rank]),
            "doc": m["doc"],
            "chunk_id": m["chunk_id"],
            "text": m["text"]
        })
    return results

def make_context(snippets):
    blocks = []
    for s in snippets:
        header = f"[{s['doc']} #chunk:{s['chunk_id']} score:{s['score']:.3f}]"
        blocks.append(f"{header}\n{s['text']}")
    return "\n\n---\n\n".join(blocks)

# --- Azure OpenAI client (expects env vars already set) ---
missing = [k for k in ["AZURE_OPENAI_ENDPOINT","AZURE_OPENAI_API_KEY","AZURE_OPENAI_API_VERSION","AZURE_OPENAI_DEPLOYMENT"] if not os.getenv(k)]
if missing:
    raise SystemExit(f"Missing env vars: {missing}. Set them before running this cell.")

client = AzureOpenAI(
    api_key=os.environ["AZURE_OPENAI_API_KEY"],
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
    api_version=os.environ["AZURE_OPENAI_API_VERSION"],
)

def answer_with_rag(question: str, top_k: int = TOP_K):
    hits = retrieve(question, k=top_k)
    context = make_context(hits)
    prompt = (
        "Use the CONTEXT to answer the QUESTION concisely. "
        "If the answer is not in the context, say you don't know.\n\n"
        f"QUESTION:\n{question}\n\n"
        f"CONTEXT:\n{context}\n\n"
        "Return citations like [doc #chunk:X]."
    )
    resp = client.chat.completions.create(
        model=os.environ["AZURE_OPENAI_DEPLOYMENT"],  # deployment name, e.g., gpt-35-turbo
        messages=[
            {"role":"system","content":"You are a helpful assistant. Always cite sources as [doc #chunk:X]."},
            {"role":"user","content": prompt}
        ],
        temperature=0.2,
    )
    return resp.choices[0].message.content, hits

# --- Ask the question ---
print("\n=== QUESTION ===")
print(QUESTION)
answer, sources = answer_with_rag(QUESTION, top_k=TOP_K)

print("\n=== ANSWER ===")
print(answer)

print("\n=== SOURCES ===")
for s in sources:
    print(f"{s['rank']:>2}. {s['doc']}  #chunk:{s['chunk_id']}  score:{s['score']:.3f}")
# Out:
# Mounted at /content/drive
# Place files in: /content/drive/MyDrive
# Found files: ['vdoc.pub_programming-quantum-computers-essential-algorithms-and-code-samples.pdf', 'vdoc.pub_fe-electrical-and-computer-practice-problems.pdf', 'quantum_fractals (1).docx', 'quantum_fractals.docx', 'dokumen.pub_david-bohm-a-life-dedicated-to-understanding-the-quantum-world-3030227146.pdf', 'vdoc.pub_techniques-and-applications-of-path-integration.pdf', 'dokumen.pub_julian-schwinger-the-physicist-the-teacher-and-the-man-9810225318-9810225326.pdf', 'Kroeger.FractalgeometryinfieldtheoryPR323p812000101s (1) (1).pdf', 'Kroeger.FractalgeometryinfieldtheoryPR323p812000101s (2) (1).pdf', 'Kroeger.FractalgeometryinfieldtheoryPR323p812000101s (4).pdf', 'vdoc.pub_basic-concepts-in-computational-physics (1).pdf', 'FeynmanHibbs (1).pdf', 'vdoc.pub_fractal-functions-fractal-surfaces-and-wavelets (1).pdf', 'vdoc (1).pub_fractal-physiology.pdf', 'vdoc.pub_fractional-calculus-an-introduction-for-physicists (1).pdf', 'vdoc.pub_fractional-derivatives-for-physicists-and-engineers-volume-i-background-and-theory-volume-ii-applications (1).pdf', 'vdoc.pub_fractional-dynamics-applications-of-fractional-calculus-to-dynamics-of-particles-fields-and-media- (1).pdf', 'vdoc.pub_fractional-order-nonlinear-systems-modeling-analysis-and-simulation- (1).pdf', 'vdoc.pub_fractional-order-systems-modeling-and-control-applications-world-scientific-series-on-nonlinear-science-series-a (1).pdf', 'vdoc.pub_fractional-quantum-mechanics (1).pdf', 'vdoc.pub_hausdorff-calculus-applications-to-fractal-systems (1).pdf', 'vdoc.pub_introduction-to-fractional-differential-equations (1).pdf', 'vdoc.pub_physics-and-fractal-structures (1).pdf', 'vdoc.pub_the-physics-of-chaos-in-hamiltonian-systems (1).pdf', 'Kroeger.FractalgeometryinfieldtheoryPR323p812000101s (1).pdf', 'Kroeger.FractalgeometryinfieldtheoryPR323p812000101s (2).pdf', 'Kroeger.FractalgeometryinfieldtheoryPR323p812000101s (3).pdf', 'Kroeger.FractalgeometryinfieldtheoryPR323p812000101s.pdf', 'Page1_20.pdf', 'FeynmanHibbs.pdf', 'Page21_40.pdf', 'Page41_60.pdf', 'Page61_80.pdf', 'Q_Accelerator_Revised__Long.pdf', 'Page81_100.pdf', 'rsta.2014.0224.pdf', 'qutip-Users_Guide_doc-4.7.pdf', 'vdoc.pub_basic-concepts-in-computational-physics.pdf', 'vdoc.pub_fractal-functions-fractal-surfaces-and-wavelets.pdf', 'vdoc.pub_fractal-physiology.pdf', 'vdoc.pub_fractional-calculus-an-introduction-for-physicists.pdf', 'vdoc.pub_fractional-derivatives-for-physicists-and-engineers-volume-i-background-and-theory-volume-ii-applications.pdf', 'vdoc.pub_fractional-order-nonlinear-systems-modeling-analysis-and-simulation-.pdf', 'vdoc.pub_fractional-dynamics-applications-of-fractional-calculus-to-dynamics-of-particles-fields-and-media-.pdf', 'vdoc.pub_fractional-order-systems-modeling-and-control-applications-world-scientific-series-on-nonlinear-science-series-a.pdf', 'vdoc.pub_fractional-quantum-mechanics.pdf', 'vdoc.pub_hausdorff-calculus-applications-to-fractal-systems.pdf', 'vdoc.pub_introduction-to-fractional-differential-equations.pdf', 'vdoc.pub_physics-and-fractal-structures.pdf', 'vdoc.pub_quantum-fluctuations.pdf', 'vdoc.pub_the-physics-of-chaos-in-hamiltonian-systems.pdf', 'dokumen.pub_asterisk-telephony-solutions-installing-and-customizing-asterisk-14-9780321525666-0321525663.pdf', 'dokumen.pub_asterisk-the-definitive-guide-open-source-telephony-for-the-enterprise-5nbsped-1492031607-9781492031604.pdf', 'dokumen.pub_data-preparation-for-machine-learning-data-cleaning-feature-selection-and-data.pdf', 'dokumen.pub_building-an-enterprise-chatbot-work-with-protected-enterprise-data-using-open-source-frameworks-1st-ed-978-1-4842-5033-4-978-1-4842-5034-1.pdf', 'vdoc.pub_foundations-of-predictive-analytics.pdf', 'dokumen.pub_text-analytics-advances-and-challenges-1st-ed-9783030526795-9783030526801.pdf', 'dokumen.pub_blueprints-for-text-analytics-using-python-machine-learning-based-solutions-for-common-real-world-nlp-applications-1nbsped-149207408x-9781492074083.pdf', 'vdoc.pub_social-network-data-analytics.pdf', 'vdoc.pub ...
# WARNING:pypdf._reader:Ignoring wrong pointing object 8 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 30 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 733 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 3195 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 8750 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 18171 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 0 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 776 0 (offset 605375)
# WARNING:pypdf._reader:Ignoring wrong pointing object 777 0 (offset 605714)
# WARNING:pypdf._reader:Ignoring wrong pointing object 778 0 (offset 605810)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2890 0 (offset 2919369)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2891 0 (offset 2919485)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2892 0 (offset 2919640)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2893 0 (offset 2924623)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2894 0 (offset 2924979)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2895 0 (offset 2925076)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2896 0 (offset 2925173)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2897 0 (offset 2925269)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2898 0 (offset 2930149)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2899 0 (offset 2930556)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2900 0 (offset 2930652)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2901 0 (offset 2930749)
# WARNING:pypdf._reader:Object 776 0 not defined.
# WARNING:pypdf._reader:Object 2890 0 not defined.
# WARNING:pypdf._reader:Object 2893 0 not defined.
# WARNING:pypdf._reader:Object 2898 0 not defined.
# ---------------------------------------------------------------------------
# PdfReadError                              Traceback (most recent call last)
# /tmp/ipython-input-3664099338.py in <cell line: 0>()
#      93     if p.suffix.lower() not in [".pdf", ".docx", ".txt", ".md"]:
#      94         continue
# ---> 95     raw = read_file(p)
#      96     txt = clean_text(raw)
#      97     if not txt.strip():
#
# /tmp/ipython-input-3664099338.py in read_file(path)
#      55             reader = PdfReader(f)
#      56             for pg in reader.pages:
# ---> 57                 text.append(pg.extract_text() or "")
#      58         return "\n".join(text)
#      59     if suf == ".docx":
#
# /usr/local/lib/python3.12/dist-packages/pypdf/_page.py in extract_text(self, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text, extraction_mode, *args, **kwargs)
#    2036             orientations = (orientations,)
#    2037
# -> 2038         return self._extract_text(
#    2039             self,
#    2040             self.pdf,
#
# /usr/local/lib/python3.12/dist-packages/pypdf/_page.py in _extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    1719         extractor.initialize_extraction(orientations, visitor_text, cmaps)
#    1720
# -> 1721         for operands, operator in content.operations:
#    1722             if visitor_operand_before is not None:
#    1723                 visitor_operand_before(operator, operands, extractor.cm_matrix, extractor.tm_matrix)
#
# /usr/local/lib/python3.12/dist-packages/pypdf/generic/_data_structures.py in operations(self)
#    1404     def operations(self) -> list[tuple[Any, bytes]]:
#    1405         if not self._operations and self._data:
# -> 1406             self._parse_content_stream(BytesIO(self._data))
#    1407             self._data = b""
#    1408         return self._operations
#
# /usr/local/lib/python3.12/dist-packages/pypdf/generic/_data_structures.py in _parse_content_stream(self, stream)
#    1297                     peek = stream.read(1)
#    1298             else:
# -> 1299                 operands.append(read_object(stream, None, self.forced_encoding))
#    1300
#    1301     def _read_inline_image(self, stream: StreamType) -> dict[str, Any]:
#
# /usr/local/lib/python3.12/dist-packages/pypdf/generic/_data_structures.py in read_object(stream, pdf, forced_encoding)
#    1446         return read_hex_string_from_stream(stream, forced_encoding)
#    1447     if tok == b"[":
# -> 1448         return ArrayObject.read_from_stream(stream, pdf, forced_encoding)
#    1449     if tok in (b"t", b"f"):
#    1450         return BooleanObject.read_from_stream(stream)
#
# /usr/local/lib/python3.12/dist-packages/pypdf/generic/_data_structures.py in read_from_stream(stream, pdf, forced_encoding)
#     259             stream.seek(-1, 1)
#     260             # read and append object
# --> 261             arr.append(read_object(stream, pdf, forced_encoding))
#     262         return arr
#     263
#
# /usr/local/lib/python3.12/dist-packages/pypdf/generic/_data_structures.py in read_object(stream, pdf, forced_encoding)
#    1454         return NullObject()
#    1455     if tok == b"n":
# -> 1456         return NullObject.read_from_stream(stream)
#    1457     if tok == b"%":
#    1458         # comment
#
# /usr/local/lib/python3.12/dist-packages/pypdf/generic/_base.py in read_from_stream(stream)
#     235         nulltxt = stream.read(4)
#     236         if nulltxt != b"null":
# --> 237             raise PdfReadError("Could not read Null object")
#     238         return NullObject()
#     239
#
# PdfReadError: Could not read Null object
