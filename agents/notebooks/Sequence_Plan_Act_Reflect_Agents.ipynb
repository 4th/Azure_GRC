# %% [markdown]
# # Assembled Notebook — SK Agents (Sequence: Plan→Act→Reflect)
# _Generated 2025-11-07T19:20:35.141052Z_

# %%
# %% [SETUP]
# !pip install -U semantic-kernel
# !pip -q uninstall -y pydrive2  # avoid OpenSSL/pyOpenSSL conflicts on Colab

# %%
# %% [SETUP-ENV]
import os, getpass
os.environ.setdefault('AZURE_OPENAI_ENDPOINT', 'https://4th-openai-resource.openai.azure.com')
os.environ.setdefault('AZURE_OPENAI_DEPLOYMENT', 'gpt-35-turbo')
os.environ.setdefault('AZURE_OPENAI_API_VERSION', '2024-10-21')
if not os.getenv('AZURE_OPENAI_API_KEY'):
    os.environ['AZURE_OPENAI_API_KEY'] = getpass.getpass('Enter AZURE_OPENAI_API_KEY (hidden): ').strip()
print('Azure OpenAI env ready (key is session-only).')

# %%
# %% [KERNEL]
import os
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

kernel = Kernel()

service = AzureChatCompletion(
    service_id='azure',
    api_key=os.getenv('AZURE_OPENAI_API_KEY'),
    deployment_name=os.getenv('AZURE_OPENAI_DEPLOYMENT'),
    endpoint=os.getenv('AZURE_OPENAI_ENDPOINT'),
)
kernel.add_service(service)
print('Kernel ready (Azure OpenAI)')

# %%
# %% [TOOLS]

def tool_safety_pre(**kwargs):
    """Safety Pre integration placeholder."""
    # TODO: implement integration with: Safety Pre
    return "stub:Safety Pre " + str(kwargs)

def tool_tool_s(**kwargs):
    """Tool(s) integration placeholder."""
    # TODO: implement integration with: Tool(s)
    return "stub:Tool(s) " + str(kwargs)

def tool_ai_search(**kwargs):
    """AI Search integration placeholder."""
    # TODO: implement integration with: AI Search
    return "stub:AI Search " + str(kwargs)

def tool_model(**kwargs):
    """Model integration placeholder."""
    # TODO: implement integration with: Model
    return "stub:Model " + str(kwargs)

def tool_safety_post(**kwargs):
    """Safety Post integration placeholder."""
    # TODO: implement integration with: Safety Post
    return "stub:Safety Post " + str(kwargs)

def tool_insights_trace(**kwargs):
    """Insights / Trace integration placeholder."""
    # TODO: implement integration with: Insights / Trace
    return "stub:Insights / Trace " + str(kwargs)


TOOLS = {

    'tool_safety_pre': tool_safety_pre,

    'tool_tool_s': tool_tool_s,

    'tool_ai_search': tool_ai_search,

    'tool_model': tool_model,

    'tool_safety_post': tool_safety_post,

    'tool_insights_trace': tool_insights_trace,

}
print('Tools:', list(TOOLS.keys()))

# %%
# %% [AGENTS]

class Agent_pva_channel:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "PVA / Channel"
        self.system_message = "You are the PVA / Channel capability agent."
        self.skills = ["tool_insights_trace"]

    async def run(self, user_text: str) -> str:
        try:
            # DEMO will patch to force service_id='azure'.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[PVA / Channel stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_apim:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "APIM"
        self.system_message = "You are the APIM capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            # DEMO will patch to force service_id='azure'.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[APIM stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_orchestrator:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Orchestrator"
        self.system_message = "You are the Orchestrator capability agent."
        self.skills = ["tool_ai_search", "tool_insights_trace", "tool_model", "tool_safety_post", "tool_safety_pre", "tool_tool_s"]

    async def run(self, user_text: str) -> str:
        try:
            # DEMO will patch to force service_id='azure'.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Orchestrator stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_planner:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Planner"
        self.system_message = "You are the Planner capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            # DEMO will patch to force service_id='azure'.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Planner stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)


# Instances

agent_pva_channel = Agent_pva_channel(kernel)

agent_apim = Agent_apim(kernel)

agent_orchestrator = Agent_orchestrator(kernel)

agent_planner = Agent_planner(kernel)

print('Agents:', ['agent_pva_channel', 'agent_apim', 'agent_orchestrator', 'agent_planner'])

# %%
# %% [WIRES]
WIRES = {
  "PVA / Channel": {
    "tools": [
      "tool_insights_trace"
    ]
  },
  "APIM": {
    "tools": []
  },
  "Orchestrator": {
    "tools": [
      "tool_ai_search",
      "tool_insights_trace",
      "tool_model",
      "tool_safety_post",
      "tool_safety_pre",
      "tool_tool_s"
    ]
  },
  "Planner": {
    "tools": []
  }
}
print('Wiring entries:', len(WIRES))

# %%
# %% [DEMO]
import os, getpass, types, asyncio
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

# Ensure env & azure service
os.environ.setdefault("AZURE_OPENAI_ENDPOINT",    "https://4th-openai-resource.openai.azure.com")
os.environ.setdefault("AZURE_OPENAI_DEPLOYMENT",  "gpt-35-turbo")
os.environ.setdefault("AZURE_OPENAI_API_VERSION", "2024-10-21")
if not os.getenv("AZURE_OPENAI_API_KEY"):
    os.environ["AZURE_OPENAI_API_KEY"] = getpass.getpass("Enter AZURE_OPENAI_API_KEY (hidden): ").strip()

try:
    kernel
except NameError:
    kernel = Kernel()
try:
    kernel.remove_service("azure")
except Exception:
    pass
kernel.add_service(AzureChatCompletion(
    service_id="azure",
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    deployment_name=os.getenv("AZURE_OPENAI_DEPLOYMENT"),
    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
))

# Patch all agents' run() to force service_id='azure'
async def _run_with_azure(self, user_text: str):
    prompt = (getattr(self, "system_message", "") or "") + "\\n\\nUser: " + str(user_text)
    result = await self.kernel.invoke_prompt(prompt, service_id="azure")
    return str(result)

patched = []
for name, obj in list(globals().items()):
    if name.startswith("agent_"):
        try:
            obj.kernel = kernel
            obj.run = types.MethodType(_run_with_azure, obj)
            patched.append(name)
        except Exception:
            pass
print("Patched run() for:", patched if patched else "(none)")

# Pick an agent with tools if possible; otherwise first
async def demo():
    candidates = [v for k,v in globals().items() if k.startswith("agent_") and getattr(v, "skills", None)]
    agent = candidates[0] if candidates else globals()[next((n for n in sorted(globals()) if n.startswith("agent_")), None)]
    print("Agent:", getattr(agent, "name", "(unknown)"))
    tools = agent.available_tools() if hasattr(agent, "available_tools") else []
    print("Tools:", tools)
    if tools:
        print("Tool demo:", tools[0], "->", agent.call(tools[0], example="value"))
    print("LLM demo:")
    try:
        out = await agent.run("In one sentence, explain your role in the one-turn plan/act/reflect flow.")
        print(out)
    except Exception as e:
        print("[demo] invoke failed:", e)

await demo()
