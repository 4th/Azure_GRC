# %% [markdown]
# # Assembled Notebook — SK Agents (Trust Boundary)
# _Generated 2025-11-07T17:41:39.001438Z_

# %%
# %% [SETUP]
# !pip install -U semantic-kernel
# !pip -q uninstall -y pydrive2  # avoid OpenSSL/cryptography conflicts in Colab

# %%
# %% [SETUP-ENV]
import os, getpass
os.environ.setdefault('AZURE_OPENAI_ENDPOINT', 'https://4th-openai-resource.openai.azure.com')
os.environ.setdefault('AZURE_OPENAI_DEPLOYMENT', 'gpt-35-turbo')
os.environ.setdefault('AZURE_OPENAI_API_VERSION', '2024-10-21')
if not os.getenv('AZURE_OPENAI_API_KEY'):
    os.environ['AZURE_OPENAI_API_KEY'] = getpass.getpass('Enter AZURE_OPENAI_API_KEY (hidden): ').strip()
print('Azure OpenAI env ready (key is session-only).')

# %%
# %% [KERNEL]
import os
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

kernel = Kernel()

service = AzureChatCompletion(
    service_id="azure",
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    deployment_name=os.getenv("AZURE_OPENAI_DEPLOYMENT"),
    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    # api_version=os.getenv("AZURE_OPENAI_API_VERSION"),  # optional
)
kernel.add_service(service)
print("Kernel ready (Azure OpenAI)")

# %%
# %% [TOOLS]

def tool_pe_azure_openai(**kwargs):
    """PE → Azure OpenAI integration placeholder."""
    # TODO: implement integration with: PE → Azure OpenAI
    return "stub:PE → Azure OpenAI " + str(kwargs)

def tool_api_management(**kwargs):
    """API Management integration placeholder."""
    # TODO: implement integration with: API Management
    return "stub:API Management " + str(kwargs)

def tool_key_vault_tenant_a(**kwargs):
    """Key Vault (Tenant A) integration placeholder."""
    # TODO: implement integration with: Key Vault (Tenant A)
    return "stub:Key Vault (Tenant A) " + str(kwargs)

def tool_app_insights_siem(**kwargs):
    """App Insights / SIEM integration placeholder."""
    # TODO: implement integration with: App Insights / SIEM
    return "stub:App Insights / SIEM " + str(kwargs)

def tool_azure_openai_provider(**kwargs):
    """Azure OpenAI (Provider) integration placeholder."""
    # TODO: implement integration with: Azure OpenAI (Provider)
    return "stub:Azure OpenAI (Provider) " + str(kwargs)

def tool_pe_storage(**kwargs):
    """PE → Storage integration placeholder."""
    # TODO: implement integration with: PE → Storage
    return "stub:PE → Storage " + str(kwargs)

def tool_app_gateway_waf(**kwargs):
    """App Gateway / WAF integration placeholder."""
    # TODO: implement integration with: App Gateway / WAF
    return "stub:App Gateway / WAF " + str(kwargs)

def tool_pe_ai_search(**kwargs):
    """PE → AI Search integration placeholder."""
    # TODO: implement integration with: PE → AI Search
    return "stub:PE → AI Search " + str(kwargs)

def tool_blob_files_storage_provider(**kwargs):
    """Blob/Files Storage (Provider) integration placeholder."""
    # TODO: implement integration with: Blob/Files Storage (Provider)
    return "stub:Blob/Files Storage (Provider) " + str(kwargs)

def tool_ai_search_provider(**kwargs):
    """AI Search (Provider) integration placeholder."""
    # TODO: implement integration with: AI Search (Provider)
    return "stub:AI Search (Provider) " + str(kwargs)


TOOLS = {

    'tool_pe_azure_openai': tool_pe_azure_openai,

    'tool_api_management': tool_api_management,

    'tool_key_vault_tenant_a': tool_key_vault_tenant_a,

    'tool_app_insights_siem': tool_app_insights_siem,

    'tool_azure_openai_provider': tool_azure_openai_provider,

    'tool_pe_storage': tool_pe_storage,

    'tool_app_gateway_waf': tool_app_gateway_waf,

    'tool_pe_ai_search': tool_pe_ai_search,

    'tool_blob_files_storage_provider': tool_blob_files_storage_provider,

    'tool_ai_search_provider': tool_ai_search_provider,

}
print('Tools:', list(TOOLS.keys()))

# %%
# %% [AGENTS]

class Agent_public_dns:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Public DNS"
        self.system_message = "You are the Public DNS capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Public DNS stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_app_gateway_waf:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "App Gateway / WAF"
        self.system_message = "You are the App Gateway / WAF capability agent."
        self.skills = ["tool_app_insights_siem"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[App Gateway / WAF stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_api_management:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "API Management"
        self.system_message = "You are the API Management capability agent."
        self.skills = ["tool_app_insights_siem"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[API Management stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_orchestrator_sk_langgraph:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Orchestrator (SK / LangGraph)"
        self.system_message = "You are the Orchestrator (SK / LangGraph) capability agent."
        self.skills = ["tool_app_insights_siem", "tool_key_vault_tenant_a", "tool_pe_ai_search", "tool_pe_azure_openai", "tool_pe_storage"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Orchestrator (SK / LangGraph) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_functions_adapters:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Functions / Adapters"
        self.system_message = "You are the Functions / Adapters capability agent."
        self.skills = ["tool_app_insights_siem"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Functions / Adapters stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_tool_registry:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Tool Registry"
        self.system_message = "You are the Tool Registry capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Tool Registry stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_key_vault_tenant_a:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Key Vault (Tenant A)"
        self.system_message = "You are the Key Vault (Tenant A) capability agent."
        self.skills = ["tool_app_insights_siem"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Key Vault (Tenant A) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_app_insights_siem:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "App Insights / SIEM"
        self.system_message = "You are the App Insights / SIEM capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[App Insights / SIEM stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_pe_azure_openai:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "PE → Azure OpenAI"
        self.system_message = "You are the PE \u2192 Azure OpenAI capability agent."
        self.skills = ["tool_azure_openai_provider"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[PE → Azure OpenAI stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_pe_ai_search:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "PE → AI Search"
        self.system_message = "You are the PE \u2192 AI Search capability agent."
        self.skills = ["tool_ai_search_provider"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[PE → AI Search stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_pe_storage:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "PE → Storage"
        self.system_message = "You are the PE \u2192 Storage capability agent."
        self.skills = ["tool_blob_files_storage_provider"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[PE → Storage stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_azure_openai_provider:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Azure OpenAI (Provider)"
        self.system_message = "You are the Azure OpenAI (Provider) capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Azure OpenAI (Provider) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_ai_search_provider:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "AI Search (Provider)"
        self.system_message = "You are the AI Search (Provider) capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[AI Search (Provider) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_blob_files_storage_provider:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Blob/Files Storage (Provider)"
        self.system_message = "You are the Blob/Files Storage (Provider) capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Blob/Files Storage (Provider) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)


# Instances

agent_public_dns = Agent_public_dns(kernel)

agent_app_gateway_waf = Agent_app_gateway_waf(kernel)

agent_api_management = Agent_api_management(kernel)

agent_orchestrator_sk_langgraph = Agent_orchestrator_sk_langgraph(kernel)

agent_functions_adapters = Agent_functions_adapters(kernel)

agent_tool_registry = Agent_tool_registry(kernel)

agent_key_vault_tenant_a = Agent_key_vault_tenant_a(kernel)

agent_app_insights_siem = Agent_app_insights_siem(kernel)

agent_pe_azure_openai = Agent_pe_azure_openai(kernel)

agent_pe_ai_search = Agent_pe_ai_search(kernel)

agent_pe_storage = Agent_pe_storage(kernel)

agent_azure_openai_provider = Agent_azure_openai_provider(kernel)

agent_ai_search_provider = Agent_ai_search_provider(kernel)

agent_blob_files_storage_provider = Agent_blob_files_storage_provider(kernel)

print('Agents:', ['agent_public_dns', 'agent_app_gateway_waf', 'agent_api_management', 'agent_orchestrator_sk_langgraph', 'agent_functions_adapters', 'agent_tool_registry', 'agent_key_vault_tenant_a', 'agent_app_insights_siem', 'agent_pe_azure_openai', 'agent_pe_ai_search', 'agent_pe_storage', 'agent_azure_openai_provider', 'agent_ai_search_provider', 'agent_blob_files_storage_provider'])

# %%
# %% [WIRES]
WIRES = {
  "Public DNS": {
    "tools": []
  },
  "App Gateway / WAF": {
    "tools": [
      "tool_app_insights_siem"
    ]
  },
  "API Management": {
    "tools": [
      "tool_app_insights_siem"
    ]
  },
  "Orchestrator (SK / LangGraph)": {
    "tools": [
      "tool_app_insights_siem",
      "tool_key_vault_tenant_a",
      "tool_pe_ai_search",
      "tool_pe_azure_openai",
      "tool_pe_storage"
    ]
  },
  "Functions / Adapters": {
    "tools": [
      "tool_app_insights_siem"
    ]
  },
  "Tool Registry": {
    "tools": []
  },
  "Key Vault (Tenant A)": {
    "tools": [
      "tool_app_insights_siem"
    ]
  },
  "App Insights / SIEM": {
    "tools": []
  },
  "PE \u2192 Azure OpenAI": {
    "tools": [
      "tool_azure_openai_provider"
    ]
  },
  "PE \u2192 AI Search": {
    "tools": [
      "tool_ai_search_provider"
    ]
  },
  "PE \u2192 Storage": {
    "tools": [
      "tool_blob_files_storage_provider"
    ]
  },
  "Azure OpenAI (Provider)": {
    "tools": []
  },
  "AI Search (Provider)": {
    "tools": []
  },
  "Blob/Files Storage (Provider)": {
    "tools": []
  }
}
print('Wiring entries:', len(WIRES))

# %%
# %% [DEMO]
import os, getpass, types, asyncio
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

# 1) Ensure env
os.environ.setdefault("AZURE_OPENAI_ENDPOINT",    "https://4th-openai-resource.openai.azure.com")
os.environ.setdefault("AZURE_OPENAI_DEPLOYMENT",  "gpt-35-turbo")
os.environ.setdefault("AZURE_OPENAI_API_VERSION", "2024-10-21")
if not os.getenv("AZURE_OPENAI_API_KEY"):
    os.environ["AZURE_OPENAI_API_KEY"] = getpass.getpass("Enter AZURE_OPENAI_API_KEY (hidden): ").strip()

# 2) Ensure kernel exists and has azure service
try:
    kernel
except NameError:
    kernel = Kernel()
try:
    kernel.remove_service("azure")
except Exception:
    pass
kernel.add_service(AzureChatCompletion(
    service_id="azure",
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    deployment_name=os.getenv("AZURE_OPENAI_DEPLOYMENT"),
    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
))

# 3) Rebind all agents to this kernel & patch run() to force service_id="azure"
async def _run_with_azure(self, user_text: str):
    prompt = (getattr(self, "system_message", "") or "") + "\n\nUser: " + str(user_text)
    result = await self.kernel.invoke_prompt(prompt, service_id="azure")
    return str(result)

rebound, patched = [], []
for name, obj in list(globals().items()):
    if name.startswith("agent_"):
        try:
            obj.kernel = kernel
            rebound.append(name)
            obj.run = types.MethodType(_run_with_azure, obj)
            patched.append(name)
        except Exception:
            pass
print("Rebound agents:", rebound if rebound else "(none)")
print("Patched run() for:", patched if patched else "(none)")

# 4) Demo: pick the first agent and try a tool + LLM call
async def demo():
    agent_name = next((n for n in sorted(globals()) if n.startswith("agent_")), None)
    if not agent_name:
        print("No agent_* instances found."); return
    agent = globals()[agent_name]
    print("Agent:", getattr(agent, "name", agent_name))

    tools = agent.available_tools() if hasattr(agent, "available_tools") else []
    print("Tools:", tools)
    if tools:
        try:
            print("Tool demo:", tools[0], "->", agent.call(tools[0], example="value"))
        except Exception as e:
            print("Tool call failed:", e)

    print("LLM demo:")
    try:
        out = await agent.run("Summarize your role in one sentence.")
        print(out)
    except Exception as e:
        print("[demo] invoke failed:", e)

await demo()
