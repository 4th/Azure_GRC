# %% [markdown]
# 🧠 Install Semantic Kernel
#
# To use Microsoft’s Semantic Kernel for orchestrating AI agents, planners, and connectors, install the latest version from PyPI using pip.
# Run the following command in a code cell below:

# %%
pip install -U semantic-kernel
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 6.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 3.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 893.8/893.8 kB 46.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.9/217.9 kB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.3/191.3 kB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 23.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# 💡 Note: Removing pydrive2
#
# If you see dependency warnings about cryptography or pyOpenSSL when installing Azure packages, they usually come from pydrive2, which Colab preinstalls for legacy Google Drive APIs.
# You don’t actually need pydrive2 for Drive access anymore — Colab’s built-in drive.mount() handles everything.
#
# To remove it safely and avoid version conflicts, run:

# %%
# !pip -q uninstall -y pydrive2

# %% [markdown]
# 🤖 Connect to Azure OpenAI in Colab
#
# The following code shows how to connect Google Colab to your Azure OpenAI resource using the official openai Python package.
#
# Import the AzureOpenAI client class.
#
# Initialize it with your Azure OpenAI endpoint, API key, and API version.
#
# Use your deployment name (for example, gpt-35-turbo) as the model parameter when sending chat requests.
#
# Print the assistant’s response.
#
# ⚠️ Security Note: Never share your real API key in public notebooks or commits.
# Instead, store it in an environment variable (for example,
# os.environ["AZURE_OPENAI_API_KEY"]) and reference it securely in your code.
#
# Run the next code cell to send a test message to your Azure OpenAI deployment and confirm the connection from Colab.

# %%
from openai import AzureOpenAI

# Initialize client
client = AzureOpenAI(
    api_key="XXXXXX",
    azure_endpoint="XXXXXX",
    api_version="2024-10-21"
)

# Correct model name = deployment name (not 'gpt-4' etc.)
response = client.chat.completions.create(
    model="gpt-35-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful AI assistant."},
        {"role": "user", "content": "Hello from Colab and Azure OpenAI!"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Hello! How can I assist you today?

# %% [markdown]
# ## Generated Capability Agents (from Markdown)
# The diagram was used to synthesize the code below; it is **not** embedded in this notebook.

# %%
# %% [KERNEL]
import os
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

kernel = Kernel()

service = AzureChatCompletion(
    service_id="azure",
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    deployment_name=os.getenv("AZURE_OPENAI_DEPLOYMENT"),  # your AOAI deployment name
    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),           # e.g. https://my-aoai.openai.azure.com
    # api_version is optional (defaults internally); set if you need a specific one:
    # api_version="2024-10-21"
)

kernel.add_service(service)
print("Kernel ready (Azure OpenAI)")

# %%
def tool_model_apis_llm(**kwargs):
    """Model APIs (LLM) integration placeholder."""
    # TODO: Implement integration with: Model APIs (LLM)
    return "stub:Model APIs (LLM) " + str(kwargs)

def tool_tools_connectors(**kwargs):
    """Tools / Connectors integration placeholder."""
    # TODO: Implement integration with: Tools / Connectors
    return "stub:Tools / Connectors " + str(kwargs)

def tool_key_vault_secrets(**kwargs):
    """Key Vault / Secrets integration placeholder."""
    # TODO: Implement integration with: Key Vault / Secrets
    return "stub:Key Vault / Secrets " + str(kwargs)

def tool_storage_docs_artifacts(**kwargs):
    """Storage (docs/artifacts) integration placeholder."""
    # TODO: Implement integration with: Storage (docs/artifacts)
    return "stub:Storage (docs/artifacts) " + str(kwargs)

def tool_ai_search_vector_index(**kwargs):
    """AI Search / Vector Index integration placeholder."""
    # TODO: Implement integration with: AI Search / Vector Index
    return "stub:AI Search / Vector Index " + str(kwargs)

def tool_api_management(**kwargs):
    """API Management integration placeholder."""
    # TODO: Implement integration with: API Management
    return "stub:API Management " + str(kwargs)

def tool_identity_rbac_entra_id(**kwargs):
    """Identity & RBAC (Entra ID) integration placeholder."""
    # TODO: Implement integration with: Identity & RBAC (Entra ID)
    return "stub:Identity & RBAC (Entra ID) " + str(kwargs)

def tool_observability_insights_otel(**kwargs):
    """Observability (Insights/OTEL) integration placeholder."""
    # TODO: Implement integration with: Observability (Insights/OTEL)
    return "stub:Observability (Insights/OTEL) " + str(kwargs)


TOOLS = {

    'tool_model_apis_llm': tool_model_apis_llm,

    'tool_tools_connectors': tool_tools_connectors,

    'tool_key_vault_secrets': tool_key_vault_secrets,

    'tool_storage_docs_artifacts': tool_storage_docs_artifacts,

    'tool_ai_search_vector_index': tool_ai_search_vector_index,

    'tool_api_management': tool_api_management,

    'tool_identity_rbac_entra_id': tool_identity_rbac_entra_id,

    'tool_observability_insights_otel': tool_observability_insights_otel,

}
print('Tools:', list(TOOLS.keys()))

# %%
class Agent_channels_pva_copilot_web:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Channels (PVA / Copilot / Web)"
        self.system_message = "You are the Channels (PVA / Copilot / Web) capability agent."
        self.skills = ["tool_api_management"]

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Channels (PVA / Copilot / Web) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_conversation_ux_turn_memory:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Conversation UX & Turn Memory"
        self.system_message = "You are the Conversation UX & Turn Memory capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Conversation UX & Turn Memory stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_prompt_templates_response_composer:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Prompt Templates & Response Composer"
        self.system_message = "You are the Prompt Templates & Response Composer capability agent."
        self.skills = ["tool_storage_docs_artifacts"]

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Prompt Templates & Response Composer stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_feedback_ratings:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Feedback & Ratings"
        self.system_message = "You are the Feedback & Ratings capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Feedback & Ratings stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_hybrid_search_bm25_vector:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Hybrid Search (BM25 + Vector)"
        self.system_message = "You are the Hybrid Search (BM25 + Vector) capability agent."
        self.skills = ["tool_ai_search_vector_index"]

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Hybrid Search (BM25 + Vector) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_reranker_scorer:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Reranker / Scorer"
        self.system_message = "You are the Reranker / Scorer capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Reranker / Scorer stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_grounding_packet_builder:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Grounding Packet Builder"
        self.system_message = "You are the Grounding Packet Builder capability agent."
        self.skills = ["tool_storage_docs_artifacts"]

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Grounding Packet Builder stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_citation_assembler:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Citation Assembler"
        self.system_message = "You are the Citation Assembler capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Citation Assembler stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_planner_sk_maf:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Planner (SK / MAF)"
        self.system_message = "You are the Planner (SK / MAF) capability agent."
        self.skills = ["tool_model_apis_llm"]

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Planner (SK / MAF) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_langgraph_flows:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "LangGraph Flows"
        self.system_message = "You are the LangGraph Flows capability agent."
        self.skills = ["tool_model_apis_llm"]

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[LangGraph Flows stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_tool_router_arg_schema:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Tool Router & Arg Schema"
        self.system_message = "You are the Tool Router & Arg Schema capability agent."
        self.skills = ["tool_tools_connectors"]

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Tool Router & Arg Schema stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_budget_step_caps:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Budget / Step Caps"
        self.system_message = "You are the Budget / Step Caps capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Budget / Step Caps stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_policy_engine_allow_deny_data_scope:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Policy Engine (allow/deny, data scope)"
        self.system_message = "You are the Policy Engine (allow/deny, data scope) capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Policy Engine (allow/deny, data scope) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_safety_gates_pre_post:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Safety Gates (pre/post)"
        self.system_message = "You are the Safety Gates (pre/post) capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Safety Gates (pre/post) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_slo_sla_cost_governance:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "SLO/SLA & Cost Governance"
        self.system_message = "You are the SLO/SLA & Cost Governance capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[SLO/SLA & Cost Governance stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_audit_compliance_logs_residency:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Audit & Compliance (logs, residency)"
        self.system_message = "You are the Audit & Compliance (logs, residency) capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Audit & Compliance (logs, residency) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)


# Instances

agent_channels_pva_copilot_web = Agent_channels_pva_copilot_web(kernel)

agent_conversation_ux_turn_memory = Agent_conversation_ux_turn_memory(kernel)

agent_prompt_templates_response_composer = Agent_prompt_templates_response_composer(kernel)

agent_feedback_ratings = Agent_feedback_ratings(kernel)

agent_hybrid_search_bm25_vector = Agent_hybrid_search_bm25_vector(kernel)

agent_reranker_scorer = Agent_reranker_scorer(kernel)

agent_grounding_packet_builder = Agent_grounding_packet_builder(kernel)

agent_citation_assembler = Agent_citation_assembler(kernel)

agent_planner_sk_maf = Agent_planner_sk_maf(kernel)

agent_langgraph_flows = Agent_langgraph_flows(kernel)

agent_tool_router_arg_schema = Agent_tool_router_arg_schema(kernel)

agent_budget_step_caps = Agent_budget_step_caps(kernel)

agent_policy_engine_allow_deny_data_scope = Agent_policy_engine_allow_deny_data_scope(kernel)

agent_safety_gates_pre_post = Agent_safety_gates_pre_post(kernel)

agent_slo_sla_cost_governance = Agent_slo_sla_cost_governance(kernel)

agent_audit_compliance_logs_residency = Agent_audit_compliance_logs_residency(kernel)

print('Agents:', ['agent_channels_pva_copilot_web', 'agent_conversation_ux_turn_memory', 'agent_prompt_templates_response_composer', 'agent_feedback_ratings', 'agent_hybrid_search_bm25_vector', 'agent_reranker_scorer', 'agent_grounding_packet_builder', 'agent_citation_assembler', 'agent_planner_sk_maf', 'agent_langgraph_flows', 'agent_tool_router_arg_schema', 'agent_budget_step_caps', 'agent_policy_engine_allow_deny_data_scope', 'agent_safety_gates_pre_post', 'agent_slo_sla_cost_governance', 'agent_audit_compliance_logs_residency'])

# %%
WIRES = {
  "Channels (PVA / Copilot / Web)": {
    "tools": [
      "API Management"
    ]
  },
  "Conversation UX & Turn Memory": {
    "tools": []
  },
  "Prompt Templates & Response Composer": {
    "tools": [
      "Storage (docs/artifacts)"
    ]
  },
  "Feedback & Ratings": {
    "tools": []
  },
  "Hybrid Search (BM25 + Vector)": {
    "tools": [
      "AI Search / Vector Index"
    ]
  },
  "Reranker / Scorer": {
    "tools": []
  },
  "Grounding Packet Builder": {
    "tools": [
      "Storage (docs/artifacts)"
    ]
  },
  "Citation Assembler": {
    "tools": []
  },
  "Planner (SK / MAF)": {
    "tools": [
      "Model APIs (LLM)"
    ]
  },
  "LangGraph Flows": {
    "tools": [
      "Model APIs (LLM)"
    ]
  },
  "Tool Router & Arg Schema": {
    "tools": [
      "Tools / Connectors"
    ]
  },
  "Budget / Step Caps": {
    "tools": []
  },
  "Policy Engine (allow/deny, data scope)": {
    "tools": []
  },
  "Safety Gates (pre/post)": {
    "tools": []
  },
  "SLO/SLA & Cost Governance": {
    "tools": []
  },
  "Audit & Compliance (logs, residency)": {
    "tools": []
  }
}
print('Wiring entries:', len(WIRES))

# %%
import asyncio
FIRST = 'agent_channels_pva_copilot_web'
async def demo():
    try:
        agent = globals()[FIRST]
        print('Agent:', agent.name)
        print('Tools:', agent.available_tools())
        t = agent.available_tools()
        if t:
            print('Tool demo:', t[0], '->', agent.call(t[0], example='value'))
        print('LLM demo:')
        print(await agent.run('Describe your role in one sentence.'))
    except Exception as e:
        print('Demo error:', e)
await demo()
