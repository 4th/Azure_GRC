# %% [markdown]
# # Assembled Notebook — SK Agents (BPMN: Escalation & Hand-off)
# _Generated 2025-11-07T18:44:14.420443Z_

# %%
# %% [SETUP]
# !pip install -U semantic-kernel
# !pip -q uninstall -y pydrive2  # avoid OpenSSL/cryptography conflicts in Colab

# %%
# %% [SETUP-ENV]
import os, getpass
os.environ.setdefault('AZURE_OPENAI_ENDPOINT', 'https://4th-openai-resource.openai.azure.com')
os.environ.setdefault('AZURE_OPENAI_DEPLOYMENT', 'gpt-35-turbo')
os.environ.setdefault('AZURE_OPENAI_API_VERSION', '2024-10-21')
if not os.getenv('AZURE_OPENAI_API_KEY'):
    os.environ['AZURE_OPENAI_API_KEY'] = getpass.getpass('Enter AZURE_OPENAI_API_KEY (hidden): ').strip()
print('Azure OpenAI env ready (key is session-only).')

# %%
# %% [KERNEL]
import os
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

kernel = Kernel()

service = AzureChatCompletion(
    service_id="azure",
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    deployment_name=os.getenv("AZURE_OPENAI_DEPLOYMENT"),
    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    # api_version=os.getenv("AZURE_OPENAI_API_VERSION"),  # optional
)
kernel.add_service(service)
print("Kernel ready (Azure OpenAI)")

# %%
# %% [TOOLS]

def tool_route_to_team_sla_timer(**kwargs):
    """Route to Team / SLA Timer integration placeholder."""
    # TODO: implement integration with: Route to Team / SLA Timer
    return "stub:Route to Team / SLA Timer " + str(kwargs)

def tool_attach_trace_context(**kwargs):
    """Attach Trace / Context integration placeholder."""
    # TODO: implement integration with: Attach Trace / Context
    return "stub:Attach Trace / Context " + str(kwargs)

def tool_schedule_callback(**kwargs):
    """Schedule Callback integration placeholder."""
    # TODO: implement integration with: Schedule Callback
    return "stub:Schedule Callback " + str(kwargs)

def tool_telemetry_trace_trace_id(**kwargs):
    """Telemetry & Trace (trace_id) integration placeholder."""
    # TODO: implement integration with: Telemetry & Trace (trace_id)
    return "stub:Telemetry & Trace (trace_id) " + str(kwargs)

def tool_close_ticket(**kwargs):
    """Close Ticket integration placeholder."""
    # TODO: implement integration with: Close Ticket
    return "stub:Close Ticket " + str(kwargs)

def tool_create_ticket(**kwargs):
    """Create Ticket integration placeholder."""
    # TODO: implement integration with: Create Ticket
    return "stub:Create Ticket " + str(kwargs)

def tool_post_hoc_eval_quality_refusal_cost(**kwargs):
    """Post-hoc Eval (quality, refusal, cost) integration placeholder."""
    # TODO: implement integration with: Post-hoc Eval (quality, refusal, cost)
    return "stub:Post-hoc Eval (quality, refusal, cost) " + str(kwargs)


TOOLS = {

    'tool_route_to_team_sla_timer': tool_route_to_team_sla_timer,

    'tool_attach_trace_context': tool_attach_trace_context,

    'tool_schedule_callback': tool_schedule_callback,

    'tool_telemetry_trace_trace_id': tool_telemetry_trace_trace_id,

    'tool_close_ticket': tool_close_ticket,

    'tool_create_ticket': tool_create_ticket,

    'tool_post_hoc_eval_quality_refusal_cost': tool_post_hoc_eval_quality_refusal_cost,

}
print('Tools:', list(TOOLS.keys()))

# %%
# %% [AGENTS]

class Agent_notify_user_escalated:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Notify User (escalated)"
        self.system_message = "You are the Notify User (escalated) capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Notify User (escalated) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_callback_completed:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Callback Completed"
        self.system_message = "You are the Callback Completed capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Callback Completed stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_intent_detection_nlu:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Intent Detection / NLU"
        self.system_message = "You are the Intent Detection / NLU capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Intent Detection / NLU stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_compute_confidence_score:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Compute Confidence Score"
        self.system_message = "You are the Compute Confidence Score capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Compute Confidence Score stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_ask_clarifying_question:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Ask Clarifying Question"
        self.system_message = "You are the Ask Clarifying Question capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Ask Clarifying Question stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_plan_retrieve_try_answer:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Plan / Retrieve / Try Answer"
        self.system_message = "You are the Plan / Retrieve / Try Answer capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Plan / Retrieve / Try Answer stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_self_check_guardrails:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Self-check & Guardrails"
        self.system_message = "You are the Self-check & Guardrails capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Self-check & Guardrails stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_draft_answer_grounded:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Draft Answer (grounded)"
        self.system_message = "You are the Draft Answer (grounded) capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Draft Answer (grounded) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_agent_pickup_queue:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Agent Pickup (Queue)"
        self.system_message = "You are the Agent Pickup (Queue) capability agent."
        self.skills = ["tool_schedule_callback", "tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Agent Pickup (Queue) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_human_crafts_answer:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Human Crafts Answer"
        self.system_message = "You are the Human Crafts Answer capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Human Crafts Answer stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_schedule_callback:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Schedule Callback"
        self.system_message = "You are the Schedule Callback capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Schedule Callback stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_create_ticket:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Create Ticket"
        self.system_message = "You are the Create Ticket capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Create Ticket stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_attach_trace_context:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Attach Trace / Context"
        self.system_message = "You are the Attach Trace / Context capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Attach Trace / Context stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_route_to_team_sla_timer:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Route to Team / SLA Timer"
        self.system_message = "You are the Route to Team / SLA Timer capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Route to Team / SLA Timer stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_close_ticket:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Close Ticket"
        self.system_message = "You are the Close Ticket capability agent."
        self.skills = ["tool_telemetry_trace_trace_id"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Close Ticket stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_telemetry_trace_trace_id:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Telemetry & Trace (trace_id)"
        self.system_message = "You are the Telemetry & Trace (trace_id) capability agent."
        self.skills = ["tool_post_hoc_eval_quality_refusal_cost"]

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Telemetry & Trace (trace_id) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)

class Agent_post_hoc_eval_quality_refusal_cost:
    def __init__(self, kernel):
        self.kernel = kernel
        self.name = "Post-hoc Eval (quality, refusal, cost)"
        self.system_message = "You are the Post-hoc Eval (quality, refusal, cost) capability agent."
        self.skills = []

    async def run(self, user_text: str) -> str:
        try:
            # The DEMO cell will later patch this call to set service_id='azure' explicitly.
            result = await self.kernel.invoke_prompt(self.system_message + "\n\nUser: " + user_text)
            return str(result)
        except Exception as e:
            return f"[Post-hoc Eval (quality, refusal, cost) stub] Adjust SK call. Error: {e}"

    def available_tools(self):
        return [t for t in self.skills if t in TOOLS]

    def call(self, tool_name: str, **kwargs):
        fn = TOOLS.get(tool_name)
        if not fn:
            raise ValueError(f"Tool not found: {tool_name}")
        return fn(**kwargs)


# Instances

agent_notify_user_escalated = Agent_notify_user_escalated(kernel)

agent_callback_completed = Agent_callback_completed(kernel)

agent_intent_detection_nlu = Agent_intent_detection_nlu(kernel)

agent_compute_confidence_score = Agent_compute_confidence_score(kernel)

agent_ask_clarifying_question = Agent_ask_clarifying_question(kernel)

agent_plan_retrieve_try_answer = Agent_plan_retrieve_try_answer(kernel)

agent_self_check_guardrails = Agent_self_check_guardrails(kernel)

agent_draft_answer_grounded = Agent_draft_answer_grounded(kernel)

agent_agent_pickup_queue = Agent_agent_pickup_queue(kernel)

agent_human_crafts_answer = Agent_human_crafts_answer(kernel)

agent_schedule_callback = Agent_schedule_callback(kernel)

agent_create_ticket = Agent_create_ticket(kernel)

agent_attach_trace_context = Agent_attach_trace_context(kernel)

agent_route_to_team_sla_timer = Agent_route_to_team_sla_timer(kernel)

agent_close_ticket = Agent_close_ticket(kernel)

agent_telemetry_trace_trace_id = Agent_telemetry_trace_trace_id(kernel)

agent_post_hoc_eval_quality_refusal_cost = Agent_post_hoc_eval_quality_refusal_cost(kernel)

print('Agents:', ['agent_notify_user_escalated', 'agent_callback_completed', 'agent_intent_detection_nlu', 'agent_compute_confidence_score', 'agent_ask_clarifying_question', 'agent_plan_retrieve_try_answer', 'agent_self_check_guardrails', 'agent_draft_answer_grounded', 'agent_agent_pickup_queue', 'agent_human_crafts_answer', 'agent_schedule_callback', 'agent_create_ticket', 'agent_attach_trace_context', 'agent_route_to_team_sla_timer', 'agent_close_ticket', 'agent_telemetry_trace_trace_id', 'agent_post_hoc_eval_quality_refusal_cost'])

# %%
# %% [WIRES]
WIRES = {
  "Notify User (escalated)": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Callback Completed": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Intent Detection / NLU": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Compute Confidence Score": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Ask Clarifying Question": {
    "tools": []
  },
  "Plan / Retrieve / Try Answer": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Self-check & Guardrails": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Draft Answer (grounded)": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Agent Pickup (Queue)": {
    "tools": [
      "tool_schedule_callback",
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Human Crafts Answer": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Schedule Callback": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Create Ticket": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Attach Trace / Context": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Route to Team / SLA Timer": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Close Ticket": {
    "tools": [
      "tool_telemetry_trace_trace_id"
    ]
  },
  "Telemetry & Trace (trace_id)": {
    "tools": [
      "tool_post_hoc_eval_quality_refusal_cost"
    ]
  },
  "Post-hoc Eval (quality, refusal, cost)": {
    "tools": []
  }
}
print('Wiring entries:', len(WIRES))

# %%
# %% [DEMO]
import os, getpass, types, asyncio
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

# 1) Ensure env
os.environ.setdefault("AZURE_OPENAI_ENDPOINT",    "https://4th-openai-resource.openai.azure.com")
os.environ.setdefault("AZURE_OPENAI_DEPLOYMENT",  "gpt-35-turbo")
os.environ.setdefault("AZURE_OPENAI_API_VERSION", "2024-10-21")
if not os.getenv("AZURE_OPENAI_API_KEY"):
    os.environ["AZURE_OPENAI_API_KEY"] = getpass.getpass("Enter AZURE_OPENAI_API_KEY (hidden): ").strip()

# 2) Ensure kernel exists and has azure service
try:
    kernel
except NameError:
    kernel = Kernel()
try:
    kernel.remove_service("azure")
except Exception:
    pass
kernel.add_service(AzureChatCompletion(
    service_id="azure",
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    deployment_name=os.getenv("AZURE_OPENAI_DEPLOYMENT"),
    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
))

# 3) Rebind all agents to this kernel & patch run() to force service_id="azure"
async def _run_with_azure(self, user_text: str):
    prompt = (getattr(self, "system_message", "") or "") + "\n\nUser: " + str(user_text)
    result = await self.kernel.invoke_prompt(prompt, service_id="azure")
    return str(result)

rebound, patched = [], []
for name, obj in list(globals().items()):
    if name.startswith("agent_"):
        try:
            obj.kernel = kernel
            rebound.append(name)
            obj.run = types.MethodType(_run_with_azure, obj)
            patched.append(name)
        except Exception:
            pass
print("Rebound agents:", rebound if rebound else "(none)")
print("Patched run() for:", patched if patched else "(none)")

# 4) Demo: choose the escalation path agent (ticket create) if present; else first agent
async def demo():
    preferred = None
    for nm, ag in globals().items():
        if nm.startswith("agent_") and hasattr(ag, "name") and "Create Ticket" in ag.name:
            preferred = ag; break
    agent = preferred or globals()[next((n for n in sorted(globals()) if n.startswith("agent_")), None)]
    print("Agent:", getattr(agent, "name", "(unknown)"))

    tools = agent.available_tools() if hasattr(agent, "available_tools") else []
    print("Tools:", tools)
    if tools:
        try:
            print("Tool demo:", tools[0], "->", agent.call(tools[0], example="value"))
        except Exception as e:
            print("Tool call failed:", e)

    print("LLM demo:")
    try:
        out = await agent.run("Summarize how you escalate when confidence is low, in one sentence.")
        print(out)
    except Exception as e:
        print("[demo] invoke failed:", e)

await demo()
